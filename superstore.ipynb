# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
s=pd.read_csv("Superstore.csv",encoding="windows-1252")
s.head() # we use .head() to find top 5 records
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
s.tail() # we use .tail() to find bottom 5 records
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
s.info() # In info we find in our dataset how many numerical and categorical columns are present.
        #In superstore data set 15 categorical columns and  3 numerical columns
        # there are no null values in over dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
s.shape # we use shape to find how records(rows) and columns in our dataset. In our superstore dataset 9994 rows and 21 columns.
# Out:
# (9994, 21)

# %%
s.describe() #In describe method we get all numerical values in our dataset.
            # In describe we get a averaage,minimum,maximum of numerical values.
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
s.isnull().sum() 
#A="we use isnull to find how many null values in our dataset and sum we find total null values in our dataset.in our superstore dataset there have no null values are present"
#print(A)
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# # Top 10 products mostly sale

# %%
s["Product Name"][:10].sort_values(ascending=True)
# Out:
# 9                     Belkin F5C206VTEL 6 Outlet Surge
# 3        Bretford CR4500 Series Slim Rectangular Table
# 0                    Bush Somerset Collection Bookcase
# 8    DXL Angle-View Binders with Locking Rings by S...
# 5    Eldon Expressions Wood and Plastic Desk Access...
# 4                       Eldon Fold 'N Roll Cart System
# 1    Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 7                       Mitel 5320 IP Phone VoIP phone
# 6                                           Newell 322
# 2    Self-Adhesive Address Labels for Typewriters b...
# Name: Product Name, dtype: object

# %% [markdown]
# # Top 10 category products mostly sale

# %%
s["Category"][:10].sort_values(ascending=False)
# Out:
# 7         Technology
# 2    Office Supplies
# 4    Office Supplies
# 6    Office Supplies
# 8    Office Supplies
# 9    Office Supplies
# 0          Furniture
# 1          Furniture
# 3          Furniture
# 5          Furniture
# Name: Category, dtype: object

# %% [markdown]
# # Top 10 Sub-Category products mostly sale

# %%
s["Sub-Category"][:10].sort_values(ascending=False)
# Out:
# 3         Tables
# 4        Storage
# 7         Phones
# 2         Labels
# 5    Furnishings
# 1         Chairs
# 0      Bookcases
# 8        Binders
# 6            Art
# 9     Appliances
# Name: Sub-Category, dtype: object

# %%
s["Sales"].unique()
# Out:
# array([261.96 , 731.94 ,  14.62 , ..., 437.472,  97.98 , 243.16 ])

# %% [markdown]
# # which category sales is maximum in superstore

# %%
s['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
plt.figure(figsize=(6,7))
s['Category'].value_counts().plot.pie(autopct='%1.2f%%',explode=(0.1,0,0.1))
plt.show()

A="In Category columns 60.30% office supplies,Furniture 21.22%,Technology 18.48%. our maximum sales are office supplies "
print(A)
# Out:
# In Category columns 60.30% office supplies,Furniture 21.22%,Technology 18.48%. our maximum sales are office supplies

# %% [markdown]
# # subcategory maximum sales in superstore

# %%
s["Sub-Category"].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
x=["Binders","Paper","Furnishing","Phones","Storage","Art","Accessories","Chairs","Appliances",
   "Labels","Tabels","Envelopes","Bookcases","Fasteners","Supplies","Machines","Copiers"]
y=[1523,1370,957,889,846,796,775,617,466,364,319,254,228,217,190,115,68]
sns.barplot(x,y)
plt.title("Sub-Category sales")
plt.xlabel("categories")
plt.xticks(rotation=90)
plt.ylabel("count")
plt.show()

A="In Sub-Category Sales Binders product mostly sale in superstore and copiers are less sale. "
print(A)
# Out:
# In Sub-Category Sales Binders product mostly sale in superstore and copiers are less sale.

# %% [markdown]
# # Average profit

# %%
avg_profit=s["Profit"].mean()
avg_profit
# Out:
# 28.656896307784802

# %% [markdown]
# # Maximum Profit

# %%
max_profit=s["Profit"].max()
max_profit
# Out:
# 8399.976

# %% [markdown]
# # Minimum Profit

# %%
min_profit=s["Profit"].min()
min_profit
# Out:
# -6599.978

# %% [markdown]
# # Average Sales

# %%
avg_sales=s["Sales"].mean()
avg_sales
# Out:
# 229.8580008304938

# %% [markdown]
# # Maximum Sales

# %%
max_sales=s["Sales"].max()
max_sales
# Out:
# 22638.48

# %% [markdown]
# # Minimum Sales

# %%
min_sales=s["Sales"].min()
min_sales
# Out:
# 0.444

# %% [markdown]
# # Top 10 cities maximum sales in our superstore

# %%
s["City"].value_counts()[:10].plot(kind="bar")
plt.title("Top 10 City Sales")
plt.show()

# %% [markdown]
# # To find outliers in Sales

# %%
sns.boxplot(s.Sales)
# Out:
# <AxesSubplot:xlabel='Sales'>

# %%
Q1=s.Sales.quantile(0.25)
Q1
# Out:
# 17.28

# %%
Q2=s.Sales.quantile(0.50)
Q2
# Out:
# 54.489999999999995

# %%
Q3=s.Sales.quantile(0.75)
Q3
# Out:
# 209.94

# %%
IQR=Q3-Q1
IQR
# Out:
# 192.66

# %%
UF=Q3+1.5*IQR
UF
# Out:
# 498.93

# %%
LF=Q1-1.5*IQR
LF
# Out:
# -271.71000000000004

# %%
s['Sales'].max()
# Out:
# 22638.48

# %%
s['Sales'].min()
# Out:
# 0.444

# %%
s['Sales'].mean()
# Out:
# 229.8580008304938

# %% [markdown]
# # Analyzed maximum consumers in superstore

# %%
sns.countplot(s.Segment)
plt.show()

# %%
s['Region'].value_counts().head()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
A=s.groupby("Region")

# %%
B=A.get_group("East")['State'].value_counts()
B
# Out:
# New York                1128
# Pennsylvania             587
# Ohio                     469
# Massachusetts            135
# New Jersey               130
# Maryland                 105
# Delaware                  96
# Connecticut               82
# Rhode Island              56
# New Hampshire             27
# Vermont                   11
# District of Columbia      10
# Maine                      8
# West Virginia              4
# Name: State, dtype: int64

# %% [markdown]
# # Top 10 state maximum sales

# %%
s['State'].value_counts()[:10]
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
x=["California","New York","Texas","Pennsylvania","Washington","Illionois","Ohio","Florida","Michigin",
  "North Carolina"]
y=[2001,1128,985,587,506,492,469,383,255,249]
sns.barplot(x,y)
plt.title("Top 10 consumers State")
plt.xlabel("State")
plt.xticks(rotation=55)
plt.ylabel("count")
plt.show()

# %% [markdown]
# # Analyzing ship mode for each category in superstore

# %%
s.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # analyzed Ship mode to find which class is supplies are maximum(Standard,second,first,same day)

# %%
s['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
s["Category"].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
A=s.groupby('Category')
B=A.get_group('Furniture')['Ship Mode'].value_counts()
B
# Out:
# Standard Class    1248
# Second Class       427
# First Class        327
# Same Day           119
# Name: Ship Mode, dtype: int64

# %%
plt.figure(figsize=(10,7))
plt.title("Ship Mode From Each Category")
sns.countplot(x=s["Category"],hue=s["Ship Mode"])
plt.show()

# %%
s.head(2)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
# 1       2  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
s['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %% [markdown]
# #  Sales vs Profits Region Wise

# %%
value=s.groupby('Region').sum()[['Sales','Profit']]
value
# Out:
#                Sales       Profit
# Region
# Central  501239.8908   39706.3625
# East     678781.2400   91522.7800
# South    391721.9050   46749.4303
# West     725457.8245  108418.4489

# %%
value.plot(kind='bar',figsize=(10,5))
plt.title("Sales vs. Profits(Region)")
plt.xlabel("Region")
plt.ylabel("In Lakhs")
plt.show()

# %% [markdown]
# # Analyze profit and sales from each category

# %%
value1=s.groupby('Category').sum()[['Sales','Profit']]
value1
# Out:
#                        Sales       Profit
# Category
# Furniture        741999.7953   18451.2728
# Office Supplies  719047.0320  122490.8008
# Technology       836154.0330  145454.9481

# %%
value1.plot(kind='bar',figsize=(15,8))
plt.title("Sales vs. Profits(Sub-Category)")
plt.xlabel("Sub-Category")
plt.ylabel("In million")
plt.show()

# %% [markdown]
# # count profit vs loss

# %%
loss=(s['Profit']<=0)
loss.value_counts()
# Out:
# False    8058
# True     1936
# Name: Profit, dtype: int64

# %%
loss=(s['Profit']<=0)
s[loss]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 14        15  US-2015-118983  11/22/2015  11/26/2015  Standard Class
# 15        16  US-2015-118983  11/22/2015  11/26/2015  Standard Class
# 23        24  US-2017-156909   7/16/2017   7/18/2017    Second Class
# 27        28  US-2015-150630   9/17/2015   9/21/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9921    9922  CA-2014-111360  11/24/2014  11/30/2014  Standard Class
# 9931    9932  CA-2015-104948  11/13/2015  11/17/2015  Standard Class
# 9937    9938  CA-2016-164889    6/3/2016    6/6/2016    Second Class
# 9962    9963  CA-2015-168088   3/19/2015   3/22/2015     First Class
# 9977    9978  US-2016-103674   12/6/2016  12/10/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 3       SO-20335    Sean O'Donnell     Consumer  United States
# ...

# %%
sns.countplot(s['Profit']<=0)
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='count'>

# %%
s.head(1)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category                       Product Name  \
# 0  FUR-BO-10001798  Furniture    Bookcases  Bush Somerset Collection Bookcase
#
#     Sales  Quantity  Discount   Profit
# 0  261.96         2       0.0  41.9136
#
# [1 rows x 21 columns]

# %% [markdown]
# # Top 5 products mostly sale in superstore

# %%
s['Product Name'].value_counts()[:5]
# Out:
# Staple envelope            48
# Staples                    46
# Easy-staple paper          46
# Avery Non-Stick Binders    20
# Staples in misc. colors    19
# Name: Product Name, dtype: int64

# %% [markdown]
# # To analyze the relation between profit and sales.

# %%
plt.figure(figsize=(14,6))
plt.title("Profit vs Sales")
sns.scatterplot(s['Profit'],s['Sales'],hue=s['Region'])
plt.show()

# %%
x=s['Profit'][:100]
y=s['Sales'][:100]
plt.scatter(x,y,c='green',s=50)
plt.show()

# %%
s.head(1)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category                       Product Name  \
# 0  FUR-BO-10001798  Furniture    Bookcases  Bush Somerset Collection Bookcase
#
#     Sales  Quantity  Discount   Profit
# 0  261.96         2       0.0  41.9136
#
# [1 rows x 21 columns]

# %% [markdown]
# # To find maximum Quantity sales at time by region wise.

# %%
s["Quantity"].value_counts()[:5]
# Out:
# 3    2409
# 2    2402
# 5    1230
# 4    1191
# 1     899
# Name: Quantity, dtype: int64

# %%
A=s.groupby("Quantity")
B=A.get_group(5)["Region"].value_counts()
B
# Out:
# West       405
# East       314
# Central    310
# South      201
# Name: Region, dtype: int64

# %% [markdown]
# # To analyzed which products have not discount in superstore

# %%
not_Discount=(s['Discount']==0)
not_Discount.value_counts()
# Out:
# False    5196
# True     4798
# Name: Discount, dtype: int64

# %%
not_Discount=(s['Discount']==0)
s[not_Discount]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 5          6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 6          7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# ...      ...             ...         ...         ...             ...
# 9987    9988  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9988    9989  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID    Customer Name    Segment        Country         City  ...  \
# ...

# %%
sns.countplot(s['Discount']==0)
plt.title("Disocunt")
plt.show()

# %% [markdown]
# # to analyzed corelation of between numerical values in our dataset.

# %%
corr=s.corr()
sns.heatmap(corr,annot=True,fmt=".0%")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # To analyzed the corelation between numerical columns of diagonal shows a histogram plot and others shows scatter plot

# %%
sns.pairplot(data=s)
plt.title("Superstore")
plt.show()
