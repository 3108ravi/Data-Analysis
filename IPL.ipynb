# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("ipl data.csv")
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# # read ippl data and top 5 records

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# # check total number of columns,entries note down your findings

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %% [markdown]
# # This data set there are 636 rows and 18 columns. There are 12 categorical columns and 5 numrical columns.there are 5 columns have null values.

# %%
#find null values

# %%
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %% [markdown]
# # there are 5  columns have null values.city,winner,player_of_match,umpire1,umpire2

# %%
#drop umpire 3 columns

# %%
df.drop(["umpire3"],axis=1)
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# # drop umpire 3 columns beacause in this column we have maximum null values.

# %% [markdown]
# # Which city hosted most number of matches

# %%
plt.figure(figsize=(15,7))
B=df.groupby("city")["id"].count().sort_values(ascending=False).plot(kind="barh")

# %% [markdown]
# # find all venue of mumbai city

# %%
A=df.groupby("city")
venue=A.get_group('Mumbai')['venue'].value_counts()
venue
# Out:
# Wankhede Stadium              57
# Dr DY Patil Sports Academy    17
# Brabourne Stadium             11
# Name: venue, dtype: int64

# %% [markdown]
# # Now compare in which venue of mumbai most number of matches played (draw bar plot and write down insights)

# %%
B=A.get_group("Mumbai")
B
# Out:
#       id  season    city        date                        team1  \
# 6      7    2017  Mumbai  2017-04-09        Kolkata Knight Riders
# 9     10    2017  Mumbai  2017-04-12          Sunrisers Hyderabad
# 15    16    2017  Mumbai  2017-04-16                Gujarat Lions
# 23    24    2017  Mumbai  2017-04-22               Mumbai Indians
# 27    28    2017  Mumbai  2017-04-24       Rising Pune Supergiant
# ..   ...     ...     ...         ...                          ...
# 572  573    2015  Mumbai  2015-05-19               Mumbai Indians
# 576  577    2016  Mumbai  2016-04-09               Mumbai Indians
# 584  585    2016  Mumbai  2016-04-16               Mumbai Indians
# 589  590    2016  Mumbai  2016-04-20  Royal Challengers Bangalore
# 599  600    2016  Mumbai  2016-04-28        Kolkata Knight Riders
#
#                        team2       toss_winner toss_decision  result  \
# 6             Mumbai Indians    Mumbai Indians         field  normal
# ...

# %%
C=B.groupby("venue")["id"].count().sort_values(ascending=False).plot(kind="barh")

# %% [markdown]
# # what is the preferred choice after winning a toss in mumbai

# %%
toss=B.groupby("toss_decision")["id"].count()
toss
# Out:
# toss_decision
# bat      34
# field    51
# Name: id, dtype: int64

# %% [markdown]
# # graphical representation above quetion

# %%
graph=B.groupby("toss_decision")["id"].count().plot(kind="barh")
graph
# Out:
# <AxesSubplot:ylabel='toss_decision'>

# %% [markdown]
# # which team won most number of toss

# %%
df["winner"].sort_values().value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
toss_win=df.groupby("toss_winner")["id"].count()
toss_win.sort_values(ascending=False)
# Out:
# toss_winner
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: id, dtype: int64

# %%
graph=df.groupby("toss_winner")["id"].count().sort_values(ascending=False).plot(kind="barh")
graph
# Out:
# <AxesSubplot:ylabel='toss_winner'>

# %% [markdown]
# # Find what mumbai indians preferred after winning a toss

# %%
A=df.groupby("toss_winner")

# %%
B=A.get_group("Mumbai Indians")["toss_decision"].value_counts()
B
# Out:
# field    45
# bat      40
# Name: toss_decision, dtype: int64

# %% [markdown]
# # head to head winning count of Mumbai Indians vs Chennai Super Kings

# %%
df[((df["team1"]=="Mumbai Indians")|(df["team1"]=="Chennai Super Kings"))&((df["team2"]=="Mumbai Indians")|(df["team2"]=="Chennai Super Kings"))]["winner"].value_counts()
# Out:
# Mumbai Indians         12
# Chennai Super Kings    10
# Name: winner, dtype: int64

# %% [markdown]
# # Which team won most of the matches in mumbai?

# %%
A=df.groupby("city")
B=A.get_group("Mumbai")["winner"].value_counts()
B
# Out:
# Mumbai Indians                 45
# Chennai Super Kings             8
# Rajasthan Royals                5
# Kings XI Punjab                 5
# Royal Challengers Bangalore     5
# Deccan Chargers                 3
# Kolkata Knight Riders           3
# Pune Warriors                   3
# Rising Pune Supergiant          2
# Delhi Daredevils                2
# Rising Pune Supergiants         1
# Sunrisers Hyderabad             1
# Kochi Tuskers Kerala            1
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %% [markdown]
# # how many times each team won the toss and won the match

# %%
A=df[(df['toss_winner'] == df['winner'])]

# %%
A
# Out:
#       id  season       city        date                        team1  \
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# ..   ...     ...        ...         ...                          ...
# 629  630    2016     Kanpur  2016-05-21               Mumbai Indians
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
A.groupby("winner")["id"].count()
# Out:
# winner
# Chennai Super Kings            42
# Deccan Chargers                19
# Delhi Daredevils               33
# Gujarat Lions                  10
# Kings XI Punjab                28
# Kochi Tuskers Kerala            4
# Kolkata Knight Riders          44
# Mumbai Indians                 48
# Pune Warriors                   3
# Rajasthan Royals               34
# Rising Pune Supergiant          5
# Rising Pune Supergiants         3
# Royal Challengers Bangalore    35
# Sunrisers Hyderabad            17
# Name: id, dtype: int64

# %%
# how many times each team won the toss and won the match in mumbai

# %%
A=df[df["toss_winner"]==df["winner"]]["winner"][df["city"]=="Mumbai"].value_counts()
A
# Out:
# Mumbai Indians                 26
# Chennai Super Kings             5
# Deccan Chargers                 3
# Delhi Daredevils                2
# Rajasthan Royals                2
# Royal Challengers Bangalore     2
# Kochi Tuskers Kerala            1
# Kolkata Knight Riders           1
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %% [markdown]
# # which venue hosted most number of matches

# %%
plt.figure(figsize=(12,8))
plt.title("most number matches")
df.groupby("venue")["id"].count().plot(kind="barh")
plt.show()

# %% [markdown]
# # find how many matches chennai super kings played at M Chinnaswamy stadium?

# %%
A=df.groupby("venue")

# %%
B=A.get_group("M Chinnaswamy Stadium")["winner"].value_counts()
B
# Out:
# Royal Challengers Bangalore    30
# Mumbai Indians                  8
# Kolkata Knight Riders           6
# Kings XI Punjab                 5
# Chennai Super Kings             4
# Delhi Daredevils                3
# Rajasthan Royals                3
# Sunrisers Hyderabad             2
# Deccan Chargers                 1
# Rising Pune Supergiant          1
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %% [markdown]
# # who won most matches at M Chinnaswamy stadium?

# %%
a=df[df["venue"]=="M Chinnaswamy Stadium"]["winner"].value_counts()

# %%
a
# Out:
# Royal Challengers Bangalore    30
# Mumbai Indians                  8
# Kolkata Knight Riders           6
# Kings XI Punjab                 5
# Chennai Super Kings             4
# Delhi Daredevils                3
# Rajasthan Royals                3
# Sunrisers Hyderabad             2
# Deccan Chargers                 1
# Rising Pune Supergiant          1
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %%
df[df["season"]==2013]
# Out:
#       id  season       city        date                        team1  \
# 381  382    2013    Kolkata  2013-04-03             Delhi Daredevils
# 382  383    2013  Bangalore  2013-04-04  Royal Challengers Bangalore
# 383  384    2013  Hyderabad  2013-04-05          Sunrisers Hyderabad
# 384  385    2013      Delhi  2013-04-06             Rajasthan Royals
# 385  386    2013    Chennai  2013-04-06               Mumbai Indians
# ..   ...     ...        ...         ...                          ...
# 452  453    2013  Hyderabad  2013-05-19        Kolkata Knight Riders
# 453  454    2013      Delhi  2013-05-21          Chennai Super Kings
# 454  455    2013      Delhi  2013-05-22          Sunrisers Hyderabad
# 455  456    2013    Kolkata  2013-05-24             Rajasthan Royals
# 456  457    2013    Kolkata  2013-05-26               Mumbai Indians
#
#                      team2            toss_winner toss_decision  result  \
# ...

# %% [markdown]
# # which city hosted most number of matches in 2013

# %%
df[df["season"]==2013]["city"].value_counts()
# Out:
# Chennai       8
# Pune          8
# Mumbai        8
# Bangalore     8
# Hyderabad     8
# Jaipur        8
# Kolkata       8
# Delhi         8
# Chandigarh    6
# Dharamsala    2
# Ranchi        2
# Raipur        2
# Name: city, dtype: int64
